# %% [markdown]
# Checking the q files of rfmix

# %%
# %run ../scripts/notebook_settings_lean.py
from glob import glob

# %%
rfmix_path = "/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_females/"

# %%
q_df = pd.read_csv(rfmix_path + "chr1.rfmix.Q", sep = "\t", header=1)

# %%
q_df = q_df.sort_values(["Kindae, Zambia"])

# %%
q_df
# Out:
#     #sample  Hamadryas, Ethiopia  Kindae, Zambia  Papio, Senegal  \
# 60  PD_0724              0.93545         0.01218         0.05237
# 65  PD_0738              0.93234         0.01234         0.05532
# 66  PD_0744              0.92590         0.01293         0.06117
# 62  PD_0730              0.92561         0.01417         0.06022
# 63  PD_0736              0.91588         0.01475         0.06937
# ..      ...                  ...             ...             ...
# 30  PD_0270              0.00055         0.98114         0.00000
# 22  PD_0237              0.00000         0.98336         0.00000
# 19  PD_0225              0.00243         0.98372         0.00000
# 71  PD_0770              0.00000         0.98477         0.00000
# 68  PD_0754              0.00000         0.98614         0.00000
#
#     Ursinus, Zambia
# 60          0.00000
# 65          0.00000
# 66          0.00000
# 62          0.00000
# 63          0.00000
# ..              ...
# 30          0.01831
# 22          0.01664
# 19          0.01385
# 71          0.01523
# 68          0.01386
#
# [75 rows x 5 columns]

# %%
q_df["#sample"]
# Out:
# 60    PD_0724
# 65    PD_0738
# 66    PD_0744
# 62    PD_0730
# 63    PD_0736
#        ...
# 30    PD_0270
# 22    PD_0237
# 19    PD_0225
# 71    PD_0770
# 68    PD_0754
# Name: #sample, Length: 75, dtype: object

# %%
q_df["#sample"]
# Out:
# 60    PD_0724
# 65    PD_0738
# 66    PD_0744
# 62    PD_0730
# 63    PD_0736
#        ...
# 30    PD_0270
# 22    PD_0237
# 19    PD_0225
# 71    PD_0770
# 68    PD_0754
# Name: #sample, Length: 75, dtype: object

# %%
plt.figure(figsize=(15,10))
data_lst = [q_df["Kindae, Zambia"], q_df["Ursinus, Zambia"], q_df["Papio, Senegal"],
            q_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(q_df["#sample"], data, color=color, left=left)
    left += data

# %%
df_l = []
chromosomes = [f'chr{x}' for x in range(1, 21)]
for chrom in chromosomes:
    q_df = pd.read_csv(rfmix_path + chrom + ".rfmix.Q", sep = "\t", header=1)
    df_l.append(q_df)
q_df_autosomes = pd.concat(df_l)

# %%
q_df_autosomes_mean = q_df_autosomes.groupby(["#sample"]).mean().reset_index()

# %%
i_df = q_df_autosomes_mean
i_df = i_df.sort_values(["Kindae, Zambia"])
plt.figure(figsize=(15,10))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data

# %%
df_l = []
chromosomes = ["chrX"]
for chrom in chromosomes:
    q_df = pd.read_csv(rfmix_path + chrom + ".rfmix.Q", sep = "\t", header=1)
    df_l.append(q_df)
q_df_x = pd.concat(df_l)

# %%
q_df_x_mean = q_df_x.groupby(["#sample"]).mean().reset_index()
i_df = q_df_x_mean
i_df = i_df.sort_values(["Kindae, Zambia"])
plt.figure(figsize=(15,10))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data

# %%
ID_mapping = dict(zip(meta_data_samples["PGDP_ID"], meta_data_samples["Origin"]))
q_df_x_mean["north"] = q_df_x_mean["Papio, Senegal"] + q_df_x_mean["Hamadryas, Ethiopia"]
q_df_x_mean["Origin"] = q_df_x_mean["#sample"].map(ID_mapping)
sorted_df = q_df_x_mean.sort_values("north")
list(sorted_df.Origin)
# Out:
# ['Mahale, Tanzania',
#  'Mahale, Tanzania',
#  'Mikumi, Tanzania',
#  'Udzungwa, Tanzania',
#  'Selous, Tanzania',
#  'Udzungwa, Tanzania',
#  nan,
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  nan,
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Udzungwa, Tanzania',
#  'Ruaha, Tanzania',
#  'Ruaha, Tanzania',
#  'Ruaha, Tanzania',
#  'Issa Valley, Tanzania',
#  'Ruaha, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Gombe, Tanzania',
#  'Arusha, Tanzania',
#  'Gombe, Tanzania',
#  'Arusha, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Serengeti, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Serengeti, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Serengeti, Tanzania',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia']

# %% [markdown]
# Doing it with all

# %%
rfmix_path = "/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all/"

# %%
df_l = []
chromosomes = [f'chr{x}' for x in range(4, 21)]
for chrom in chromosomes:
    q_df = pd.read_csv(rfmix_path + chrom + ".rfmix.Q", sep = "\t", header=1)
    df_l.append(q_df)
q_df_autosomes = pd.concat(df_l)
q_df_autosomes_mean = q_df_autosomes.groupby(["#sample"]).mean().reset_index()

# %%
i_df = q_df_autosomes_mean
i_df = i_df.sort_values(["Kindae, Zambia"])
plt.figure(figsize=(15,10))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data

# %%
meta_data_samples = pd.read_csv("../data/Papio_metadata_with_clustering.txt", sep =" ")

# %%
IDs = meta_data_samples.loc[meta_data_samples.C_origin.isin([# "Cynocephalus, Central Tanzania",
                                                       "Anubis, Tanzania", "Cynocephalus, Western Tanzania"])].PGDP_ID

# %%
meta_data_samples.loc[meta_data_samples.PGDP_ID == "PD_0693"]
# Out:
#      PGDP_ID    Provider_ID                      Provider  Genus  \
# 125  PD_0693  35225_BZ12031  Rogers/Jolly/Phillips-Conroy  Papio
#
#                 Species               Origin Sex  \
# 125  ursinus (grayfoot)  Dendro Park, Zambia   F
#
#                                          address  longitude   latitude  \
# 125  Dendro Balla Balla Safaris, Namwala, Zambia   26.06255 -16.145438
#
#      callset_index         C_origin
# 125            125  Ursinus, Zambia

# %%
subset_df = q_df_autosomes_mean.loc[q_df_autosomes_mean["#sample"].isin(IDs)]

# %%
i_df = subset_df
i_df = i_df.sort_values(["Kindae, Zambia"])
plt.figure(figsize=(15,10))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data

# %%
IDs = meta_data_samples.loc[meta_data_samples.C_origin.isin(["Cynocephalus, Central Tanzania"])].PGDP_ID

# %%
subset_df = q_df_autosomes_mean.loc[q_df_autosomes_mean["#sample"].isin(IDs)]
i_df = subset_df
i_df = i_df.sort_values(["Kindae, Zambia"])
plt.figure(figsize=(15,10))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data

# %% [markdown]
# Check of the EM gradient.

# %%
rfmix_path = "/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/"

# %%
paths = glob(rfmix_path + "chr*.rfmix.Q")

# %%
paths
# Out:
# ['/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr16.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr12.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr7.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr3.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr20.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr17.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr13.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr6.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr2.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr4.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr8.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr19.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr15.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr11.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr9.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr5.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr1.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr14.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr10.rfmix.Q',
#  '/home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr18.rfmix.Q']

# %%
df_l = []
chromosomes = [f'chr{x}' for x in range(4, 21)]
for path in paths:
    print(path)
    q_df = pd.read_csv(path, sep = "\t", header=1)
    df_l.append(q_df)
q_df_autosomes = pd.concat(df_l)
q_df_autosomes_mean = q_df_autosomes.groupby(["#sample"]).mean().reset_index()
# Out:
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr16.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr12.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr7.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr3.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr20.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr17.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr13.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr6.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr2.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr4.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr8.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr19.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr15.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr11.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr9.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr5.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr1.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr14.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr10.rfmix.Q
# /home/eriks/baboondiversity/people/eriks/second_analysis_baboons/steps/rfmix_all_reanalyze5/chr18.rfmix.Q

# %%
q_df.loc[q_df["#sample"] == "PD_0393"]
# Out:
#      #sample  Hamadryas, Ethiopia  Kindae, Zambia  Papio, Senegal  \
# 163  PD_0393                  0.0             0.0             1.0
#
#      Ursinus, Zambia
# 163              0.0

# %%
q_df_autosomes_mean.sort_values(["Papio, Senegal"])
# Out:
#        #sample  Hamadryas, Ethiopia  Kindae, Zambia  Papio, Senegal  \
# 224  Sci_97124                  1.0        0.000000             0.0
# 182    PD_0760                  0.0        0.976407             0.0
# 181    PD_0759                  0.0        0.988082             0.0
# 180    PD_0758                  0.0        0.984460             0.0
# 173    PD_0751                  0.0        0.981620             0.0
# ..         ...                  ...             ...             ...
# 64     PD_0400                  0.0        0.000000             1.0
# 63     PD_0399                  0.0        0.000000             1.0
# 62     PD_0398                  0.0        0.000000             1.0
# 60     PD_0396                  0.0        0.000000             1.0
# 54     PD_0390                  0.0        0.000000             1.0
#
#      Ursinus, Zambia
# 224         0.000000
# 182         0.023593
# 181         0.011918
# 180         0.015540
# 173         0.018381
# ..               ...
# 64          0.000000
# 63          0.000000
# 62          0.000000
# 60          0.000000
# 54          0.000000
#
# [225 rows x 5 columns]

# %%
i_df = q_df_autosomes_mean
i_df["north"] = i_df["Papio, Senegal"] + i_df["Hamadryas, Ethiopia"]
i_df = i_df.sort_values(["north", "Papio, Senegal"])
plt.figure(figsize=(20,12))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data
matplotlib.pyplot.yticks(color='w')
plt.tight_layout()
plt.savefig("../steps/paint_plots/rfmix_all.png", dpi=100, format="png")

# %%
IDs = meta_data_samples.loc[meta_data_samples.C_origin.isin(["Cynocephalus, Central Tanzania"])].PGDP_ID
q_df_autosomes_mean.loc[q_df_autosomes_mean["#sample"].isin(IDs)].sort_values("north")
# Out:
#      #sample  Hamadryas, Ethiopia  Kindae, Zambia  Papio, Senegal  \
# 36   PD_0235             0.000676        0.985660        0.000000
# 37   PD_0236             0.001409        0.984204        0.000142
# 38   PD_0237             0.002381        0.983586        0.000102
# 174  PD_0752             0.003857        0.980902        0.000038
# 53   PD_0272             0.003809        0.981499        0.000447
# 168  PD_0746             0.004194        0.979809        0.000120
# 196  PD_0774             0.004381        0.979363        0.000058
# 177  PD_0755             0.004219        0.979745        0.000240
# 112  PD_0690             0.004266        0.976994        0.000204
# 190  PD_0768             0.004494        0.978449        0.000065
# 109  PD_0687             0.004444        0.980216        0.000186
# 194  PD_0772             0.004167        0.979522        0.000492
# 197  PD_0775             0.004687        0.981089        0.000096
# 175  PD_0753             0.004680        0.979400        0.000268
# 187  PD_0765             0.004811        0.979975        0.000154
# 195  PD_0773             0.004977        0.980527        0.000103
# 176  PD_0754             0.005123        0.976376        0.000145
# 191  PD_0769             0.005011        0.977835        0.000325
# 110  PD_0688             0.004930        0.979351        0.000410
# 183  PD_0761             0.005386        0.978383        0.000081
# 170  PD_0748             0.005158        0.978323        0.000331
# 188  PD_0766             0.005181        0.978638        0.000316
# 84   PD_0637             0.005547        0.979548        0.000067
# 192  PD_0770             0.005416        0.978319        0.000211
# 27   PD_0226             0.005554        0.977182        0.000114
# 52   PD_0271             0.005448        0.977719        0.000240
# 26   PD_0225             0.005498        0.978136        0.000206
# 186  PD_0764             0.005205        0.978388        0.000527
# 193  PD_0771             0.005673        0.978426        0.000080
# 179  PD_0757             0.005337        0.977663        0.000444
# 184  PD_0762             0.005660        0.976671        0.000240
# 185  PD_0763             0.005564        0.977036        0.000471
# 51   PD_0270             0.005661        0.977373        0.000391
# 24   PD_0223             0.005640        0.977578        0.000464
# 189  PD_0767             0.005779        0.977487        0.000363
# 167  PD_0745             0.005702        0.979021        0.000447
# 50   PD_0269             0.006056        0.979993        0.000142
# 113  PD_0691             0.006076        0.976182        0.000302
# 28   PD_0227             0.006296        0.978195        0.000260
# 169  PD_0747             0.006108        0.975570        0.000494
# 178  PD_0756             0.006112        0.978541        0.000669
# 111  PD_0689             0.006314        0.976592        0.000543
# 49   PD_0268             0.007042        0.976781        0.000181
# 25   PD_0224             0.018454        0.967111        0.000494
# 16   PD_0215             0.055268        0.929129        0.001982
# 15   PD_0214             0.057307        0.923297        0.002269
# 14   PD_0213             0.058757        0.922963        0.001776
# 77   PD_0503             0.061023        0.920621        0.001677
# 18   PD_0217             0.064246        0.918035        0.001379
# 17   PD_0216             0.068223        0.913335        0.002248
#
#      Ursinus, Zambia     north
# 36          0.013664  0.000676
# 37          0.014244  0.001552
# 38          0.013931  0.002484
# 174         0.015204  0.003895
# 53          0.014244  0.004256
# 168         0.015879  0.004314
# 196         0.016199  0.004439
# 177         0.015796  0.004459
# 112         0.018538  0.004470
# 190         0.016995  0.004559
# 109         0.015154  0.004631
# 194         0.015818  0.004659
# 197         0.014131  0.004783
# 175         0.015648  0.004949
# 187         0.015058  0.004966
# 195         0.014391  0.005081
# 176         0.018354  0.005267
# 191         0.016830  0.005336
# 110         0.015312  0.005340
# 183         0.016151  0.005467
# 170         0.016188  0.005489
# 188         0.015865  0.005497
# 84          0.014840  0.005614
# 192         0.016053  0.005627
# 27          0.017150  0.005668
# 52          0.016594  0.005688
# 26          0.016160  0.005704
# 186         0.015880  0.005732
# 193         0.015821  0.005753
# 179         0.016556  0.005781
# 184         0.017427  0.005901
# 185         0.016931  0.006035
# 51          0.016577  0.006052
# 24          0.016317  0.006104
# 189         0.016370  0.006142
# 167         0.014830  0.006149
# 50          0.013810  0.006198
# 113         0.017439  0.006378
# 28          0.015248  0.006557
# 169         0.017827  0.006603
# 178         0.014679  0.006781
# 111         0.016552  0.006857
# 49          0.015997  0.007223
# 25          0.013941  0.018949
# 16          0.013621  0.057250
# 15          0.017125  0.059577
# 14          0.016504  0.060533
# 77          0.016679  0.062700
# 18          0.016342  0.065625
# 17          0.016192  0.070472

# %%
ID_mapping = dict(zip(meta_data_samples["PGDP_ID"], meta_data_samples["Origin"]))
q_df_autosomes_mean["Origin"] = q_df_autosomes_mean["#sample"].map(ID_mapping)
sorted_df = q_df_autosomes_mean.sort_values("north")
list(sorted_df.Origin) #.loc[sorted_df.north > 0.0001]
# Out:
# ['Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Dendro Park, Zambia',
#  'Dendro Park, Zambia',
#  'Dendro Park, Zambia',
#  'Dendro Park, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  nan,
#  nan,
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Chunga, Zambia',
#  'Selous, Tanzania',
#  'Selous, Tanzania',
#  'Selous, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  nan,
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Udzungwa, Tanzania',
#  'Mikumi, Tanzania',
#  'Udzungwa, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Udzungwa, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  nan,
#  'Udzungwa, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Mikumi, Tanzania',
#  'Udzungwa, Tanzania',
#  'Katavi, Tanzania',
#  'Ruaha, Tanzania',
#  'Ruaha, Tanzania',
#  'Ruaha, Tanzania',
#  'Ruaha, Tanzania',
#  'Ruaha, Tanzania',
#  'Mahale, Tanzania',
#  'Ruaha, Tanzania',
#  'Katavi, Tanzania',
#  'Mahale, Tanzania',
#  'Mahale, Tanzania',
#  'Mahale, Tanzania',
#  'Mahale, Tanzania',
#  'Mahale, Tanzania',
#  'Mahale, Tanzania',
#  'Issa Valley, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Tarangire, Tanzania',
#  'Arusha, Tanzania',
#  nan,
#  'Arusha, Tanzania',
#  'Arusha, Tanzania',
#  'Arusha, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Ngorongoro, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Lake Manyara, Tanzania',
#  'Gombe, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  'Serengeti, Tanzania',
#  nan,
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Gog Woreda, Gambella region, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Niokolo-Koba, Senegal',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  nan,
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Niokolo-Koba, Senegal',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Filoha, Ethiopia',
#  'Niokolo-Koba, Senegal',
#  nan]

# %%
sorted_df.loc[sorted_df.north < 0.9999]
# Out:
#      #sample  Hamadryas, Ethiopia  Kindae, Zambia  Papio, Senegal  \
# 207  PD_0785             0.000000        0.982692        0.000000
# 202  PD_0780             0.000000        0.978739        0.000000
# 203  PD_0781             0.000000        0.981874        0.000000
# 204  PD_0782             0.000000        0.974897        0.000000
# 117  PD_0695             0.000000        0.004555        0.000000
# ..       ...                  ...             ...             ...
# 142  PD_0720             0.973085        0.001262        0.025620
# 154  PD_0732             0.974265        0.001280        0.024457
# 150  PD_0728             0.974509        0.001213        0.024247
# 143  PD_0721             0.973808        0.001053        0.025070
# 157  PD_0735             0.974282        0.001076        0.024601
#
#      Ursinus, Zambia     north                                 Origin
# 207         0.017308  0.000000                         Chunga, Zambia
# 202         0.021261  0.000000                         Chunga, Zambia
# 203         0.018125  0.000000                         Chunga, Zambia
# 204         0.025103  0.000000                         Chunga, Zambia
# 117         0.995445  0.000000                    Dendro Park, Zambia
# ..               ...       ...                                    ...
# 142         0.000034  0.998705  Gog Woreda, Gambella region, Ethiopia
# 154         0.000000  0.998722  Gog Woreda, Gambella region, Ethiopia
# 150         0.000029  0.998757  Gog Woreda, Gambella region, Ethiopia
# 143         0.000070  0.998877  Gog Woreda, Gambella region, Ethiopia
# 157         0.000040  0.998884  Gog Woreda, Gambella region, Ethiopia
#
# [187 rows x 7 columns]

# %%
meta_data_samples.loc[meta_data_samples.PGDP_ID == "PD_0752"]
# Out:
#      PGDP_ID Provider_ID Provider  Genus       Species            Origin Sex  \
# 184  PD_0752  16049_3114  Rogers   Papio  cynocephalus  Mikumi, Tanzania   M
#
#                                               address  longitude  latitude  \
# 184  Mikumi, Kilosa, Morogoro, Coastal Zone, Tanzania  36.977032 -7.404852
#
#      callset_index                        C_origin
# 184            184  Cynocephalus, Central Tanzania

# %%
IDs = meta_data_samples.loc[meta_data_samples.C_origin.isin(["Cynocephalus, Central Tanzania"])].PGDP_ID
i_df = q_df_autosomes_mean.loc[q_df_autosomes_mean["#sample"].isin(IDs)]
i_df["north"] = i_df["Papio, Senegal"] + i_df["Hamadryas, Ethiopia"]
i_df = i_df.sort_values(["north", "Papio, Senegal"])
plt.figure(figsize=(20,12))
data_lst = [i_df["Kindae, Zambia"], i_df["Ursinus, Zambia"], i_df["Papio, Senegal"],
            i_df["Hamadryas, Ethiopia"]]
color_lst = ["red", "orange", "lightblue", "blue"]
left = 0
for data, color in zip(data_lst, color_lst):
    plt.barh(i_df["#sample"], data, color=color, left=left)
    left += data
matplotlib.pyplot.yticks(color='w')
plt.tight_layout()
# Out:
# /home/eriks/miniconda3/envs/baboondiversity/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
